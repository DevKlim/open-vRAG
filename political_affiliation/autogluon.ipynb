# %%
import pandas as pd
import re
import os
import shutil
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularDataset, TabularPredictor
from sklearn.metrics import classification_report
from autogluon.multimodal import MultiModalPredictor

# %%
csv_path = "C:\\Users\\kevin\\Documents\\GitHub\\open-vRAG\\political_affiliation\\"
print(f"Loading dataset from '{csv_path}'...")

columns = [
    "id",
    "label",
    "statement",
    "subjects",
    "speaker",
    "speaker_job",
    "state",
    "party",
    "barely_true_count",
    "false_count",
    "half_true_count",
    "mostly_true_count",
    "pants_on_fire_count",
    "context"
]
df_train = pd.read_csv(csv_path + "train.tsv", sep="\t", header = None, names = columns)
df_train = df_train[df_train['party'].isin(['democrat', 'republican'])][['statement', 'party']]
df_test = pd.read_csv(csv_path + "test.tsv", sep="\t", header = None, names = columns)
df_test = df_test[df_test['party'].isin(['democrat', 'republican'])][['statement', 'party']]
# Out:
# Loading dataset from 'C:\Users\kevin\Documents\GitHub\open-vRAG\political_affiliation\'...

# %%
save_path = 'AutogluonModels/politicalAffiliation_tabular'

if os.path.exists(save_path):
    print(f"Removing existing model directory: {save_path}")
    shutil.rmtree(save_path)
# Out:
# Removing existing model directory: AutogluonModels/politicalAffiliation_tabular

# %%
predictor = TabularPredictor(
    label= 'party',
    eval_metric='accuracy',
    problem_type='binary',
    path=save_path
)

# %%
predictor.fit(
    df_train,
    time_limit=1200, # Set a shorter limit for simpler models (5 min)
    presets='medium_quality_faster_train', # Use a preset suitable for tabular data
    
    # We use included_model_types to specify only the simple models we want.
    hyperparameters={
        'LR': {},          # Logistic Regression
        'RF': {},          # Random Forest
        'XGB': {},         # XGBoost
        'XT': {},
    }
)
# Out:
# Preset alias specified: 'medium_quality_faster_train' maps to 'medium_quality'.
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.12.1
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          32
# Memory Avail:       16.12 GB / 31.74 GB (50.8%)
# Disk Space Avail:   39.40 GB / 464.32 GB (8.5%)
# ===================================================
# Presets specified: ['medium_quality_faster_train']
# Beginning AutoGluon training ... Time limit = 1200s
# AutoGluon will save models to "c:\Users\kevin\Documents\GitHub\open-vRAG\political_affiliation\AutogluonModels\politicalAffiliation_tabular"
# Train Data Rows:    7833
# Train Data Columns: 1
# Label Column:       party
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = republican, class 0 = democrat
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (republican) vs negative (democrat) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    16535.65 MB
# 	Train Data (Original)  Memory Usage: 1.17 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting TextSpecialFeatureGenerator...
# 			Fitting BinnedFeatureGenerator...
# 			Fitting DropDuplicatesFeatureGenerator...
# 		Fitting TextNgramFeatureGenerator...
# 			Fitting CountVectorizer for text features: ['statement']
# 			CountVectorizer fit with vocabulary size = 941
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('object', ['text']) : 1 | ['statement']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', ['text_as_category'])  :   1 | ['statement']
# 		('int', ['binned', 'text_special']) :  14 | ['statement.char_count', 'statement.word_count', 'statement.capital_ratio', 'statement.lower_ratio', 'statement.digit_ratio', ...]
# 		('int', ['text_ngram'])             : 927 | ['__nlp__.000', '__nlp__.000 in', '__nlp__.000 jobs', '__nlp__.000 people', '__nlp__.10', ...]
# 	4.1s = Fit runtime
# 	1 features in original data used to generate 942 features in processed data.
# 	Train Data (Processed) Memory Usage: 13.96 MB (0.1% of available memory)
# Data preprocessing and feature engineering runtime = 4.16s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.1, Train Rows: 7049, Val Rows: 784
# User-specified model hyperparameters to be fit:
# {
# 	'LR': [{}],
# 	'RF': [{}],
# 	'XGB': [{}],
# 	'XT': [{}],
# }
# Fitting 4 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest ... Training model for up to 1195.84s of the 1195.84s of remaining time.
# 	Fitting with cpus=32, gpus=0
# 	0.6467	 = Validation score   (accuracy)
# 	1.03s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: ExtraTrees ... Training model for up to 1194.69s of the 1194.68s of remaining time.
# 	Fitting with cpus=32, gpus=0
# 	0.6237	 = Validation score   (accuracy)
# 	1.11s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 1193.47s of the 1193.47s of remaining time.
# 	Fitting with cpus=24, gpus=0
# 	0.6288	 = Validation score   (accuracy)
# 	1.51s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LinearModel ... Training model for up to 1191.91s of the 1191.91s of remaining time.
# 	Fitting with cpus=32, gpus=0, mem=0.0/15.7 GB
# 	0.6084	 = Validation score   (accuracy)
# 	18.75s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 1172.98s of remaining time.
# 	Ensemble Weights: {'RandomForest': 0.625, 'XGBoost': 0.25, 'ExtraTrees': 0.125}
# 	0.6492	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 27.08s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 6486.8 rows/s (784 batch size)
# Disabling decision threshold calibration for metric `accuracy` due to having fewer than 10000 rows of validation data for calibration, to avoid overfitting (784 rows).
# 	`accuracy` is generally not improved through threshold calibration. Force calibration via specifying `calibrate_decision_threshold=True`.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("c:\Users\kevin\Documents\GitHub\open-vRAG\political_affiliation\AutogluonModels\politicalAffiliation_tabular")

# %%
print("\n--- Model Leaderboard (All Trained Models) ---")
leaderboard = predictor.leaderboard(df_test)
print(leaderboard)
# Out:
# --- Model Leaderboard (All Trained Models) ---
#                  model  score_test  score_val eval_metric  pred_time_test  \
# 0  WeightedEnsemble_L2    0.639713   0.649235    accuracy        0.389026
# 1           ExtraTrees    0.638690   0.623724    accuracy        0.148378
# 2         RandomForest    0.637666   0.646684    accuracy        0.117628
# 3          LinearModel    0.621290   0.608418    accuracy        0.205231
# 4              XGBoost    0.609007   0.628827    accuracy        0.093277
#
#    pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0       0.120861   3.663019                 0.029744                0.000000
# 1       0.046329   1.105969                 0.148378                0.046329
# 2       0.056001   1.030432                 0.117628                0.056001
# 3       0.142308  18.753004                 0.205231                0.142308
# 4       0.018531   1.505826                 0.093277                0.018531
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           0.020792            2       True          5
# 1           1.105969            1       True          2
# 2           1.030432            1       True          1
# 3          18.753004            1       True          4
# 4           1.505826            1       True          3

# %%
save_path2 = 'AutogluonModels/politicalAffiliation_multimodal'
predictor2 = MultiModalPredictor(
    label="party",
    eval_metric="accuracy",
    problem_type="binary",
    path= save_path2
)

predictor2.fit(df_train,
 time_limit=1200)
# Out:
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.12.1
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          32
# Pytorch Version:    2.7.1+cpu
# CUDA Version:       CUDA is not available
# GPU Count:          0
# Memory Avail:       14.54 GB / 31.74 GB (45.8%)
# Disk Space Avail:   39.17 GB / 464.32 GB (8.4%)
# ===================================================
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[114], line 9
#       1 save_path2 = 'AutogluonModels/politicalAffiliation_multimodal'
#       2 predictor2 = MultiModalPredictor(
#       3     label="party",
#       4     eval_metric="accuracy",
#       5     problem_type="binary",
#       6     path= save_path2
#       7 )
# ----> 9 predictor2.fit(df_train,
#      10  time_limit=1200,
#      11  presets='medium_quality_faster_train')
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\autogluon\multimodal\predictor.py:540, in MultiModalPredictor.fit(self, train_data, presets, tuning_data, max_num_tuning_data, id_mappings, time_limit, save_path, hyperparameters, column_types, holdout_frac, teacher_predictor, seed, standalone, hyperparameter_tune_kwargs, clean_ckpts, predictions, labels, predictors)
#     537     assert isinstance(predictors, list)
#     538     learners = [ele if isinstance(ele, str) else ele._learner for ele in predictors]
# --> 540 self._learner.fit(
#     541     train_data=train_data,
#     542     presets=presets,
#     543     tuning_data=tuning_data,
#     544     max_num_tuning_data=max_num_tuning_data,
#     545     time_limit=time_limit,
#     546     save_path=save_path,
#     547     hyperparameters=hyperparameters,
#     548     column_types=column_types,
#     549     holdout_frac=holdout_frac,
#     550     teacher_learner=teacher_learner,
#     551     seed=seed,
#     552     standalone=standalone,
#     553     hyperparameter_tune_kwargs=hyperparameter_tune_kwargs,
#     554     clean_ckpts=clean_ckpts,
#     555     id_mappings=id_mappings,
#     556     predictions=predictions,
#     557     labels=labels,
#     558     learners=learners,
#     559 )
#     561 return self
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\autogluon\multimodal\learners\base.py:654, in BaseLearner.fit(self, train_data, presets, tuning_data, time_limit, save_path, hyperparameters, column_types, holdout_frac, teacher_learner, seed, standalone, hyperparameter_tune_kwargs, clean_ckpts, **kwargs)
#     652 self.infer_output_shape()
#     653 self.infer_validation_metric()
# --> 654 self.update_hyperparameters(
#     655     hyperparameters=hyperparameters,
#     656     hyperparameter_tune_kwargs=hyperparameter_tune_kwargs,
#     657 )
#     658 self.fit_sanity_check()
#     659 self.prepare_fit_args(
#     660     time_limit=time_limit,
#     661     seed=seed,
#     662     standalone=standalone,
#     663     clean_ckpts=clean_ckpts,
#     664 )
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\autogluon\multimodal\learners\base.py:512, in BaseLearner.update_hyperparameters(self, hyperparameters, hyperparameter_tune_kwargs)
#     509 elif hyperparameter_tune_kwargs:
#     510     self._hyperparameter_tune_kwargs = hyperparameter_tune_kwargs
# --> 512 self._hyperparameters, self._hyperparameter_tune_kwargs = update_hyperparameters(
#     513     problem_type=problem_type,
#     514     presets=self._presets,
#     515     provided_hyperparameters=self._hyperparameters,
#     516     provided_hyperparameter_tune_kwargs=self._hyperparameter_tune_kwargs,
#     517 )
#     518 # split out the hyperparameters whose values are complex objects
#     519 self._hyperparameters, self._advanced_hyperparameters = split_hyperparameters(self._hyperparameters)
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\autogluon\multimodal\utils\config.py:648, in update_hyperparameters(problem_type, presets, provided_hyperparameters, provided_hyperparameter_tune_kwargs)
#     622 def update_hyperparameters(
#     623     problem_type,
#     624     presets,
#     625     provided_hyperparameters,
#     626     provided_hyperparameter_tune_kwargs,
#     627 ):
#     628     """
#     629     Update preset hyperparameters hyperparameter_tune_kwargs by the provided.
#     630     Currently, this is mainly used for HPO presets, which define some searchable hyperparameters.
#    (...)
#     646     The updated hyperparameters and hyperparameter_tune_kwargs.
#     647     """
# --> 648     hyperparameters, hyperparameter_tune_kwargs = get_presets(problem_type=problem_type, presets=presets)
#     650     if hyperparameter_tune_kwargs and provided_hyperparameter_tune_kwargs:
#     651         hyperparameter_tune_kwargs.update(provided_hyperparameter_tune_kwargs)
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\autogluon\multimodal\utils\presets.py:1013, in get_presets(problem_type, presets)
#    1010     problem_type = DEFAULT
#    1012 if problem_type in automm_presets.list_keys():
# -> 1013     hyperparameters, hyperparameter_tune_kwargs = automm_presets.create(problem_type, presets)
#    1014 else:
#    1015     raise ValueError(
#    1016         f"Problem type '{problem_type}' doesn't have any presets yet. "
#    1017         f"Consider one of these: {automm_presets.list_keys()}"
#    1018     )
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\autogluon\multimodal\utils\registry.py:92, in Registry.create(self, name, *args, **kwargs)
#      78 def create(self, name: str, *args, **kwargs) -> object:
#      79     """
#      80     Create the class object with the given args and kwargs
#      81     Parameters
#    (...)
#      90         The created object
#      91     """
# ---> 92     return self.get(name)(*args, **kwargs)
#
# File c:\Users\kevin\AppData\Local\Programs\Python\Python312\Lib\site-packages\autogluon\multimodal\utils\presets.py:195, in default(presets)
#     186     hyperparameters.update(
#     187         {
#     188             "model.hf_text.checkpoint_name": "microsoft/mdeberta-v3-base",
#    (...)
#     192         }
#     193     )
#     194 else:
# --> 195     raise ValueError(f"Unknown preset type: {presets}")
#     197 return hyperparameters, hyperparameter_tune_kwargs
#
# ValueError: Unknown preset type: medium_quality_faster_train

# %%
# Out:
# Preset alias specified: 'medium_quality_faster_train' maps to 'medium_quality'.
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.12.1
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          32
# Memory Avail:       12.55 GB / 31.74 GB (39.5%)
# Disk Space Avail:   39.40 GB / 464.32 GB (8.5%)
# ===================================================
# Presets specified: ['medium_quality_faster_train']
# Beginning AutoGluon training ... Time limit = 600s
# AutoGluon will save models to "c:\Users\kevin\Documents\GitHub\open-vRAG\political_affiliation\AutogluonModels\politicalAffiliation_tabular"
# Train Data Rows:    69168
# Train Data Columns: 1
# Label Column:       Party
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = Republican, class 0 = Democrat
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (Republican) vs negative (Democrat) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12857.53 MB
# 	Train Data (Original)  Memory Usage: 22.82 MB (0.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting TextSpecialFeatureGenerator...
# 			Fitting BinnedFeatureGenerator...
# 			Fitting DropDuplicatesFeatureGenerator...
# 		Fitting TextNgramFeatureGenerator...
# 			Fitting CountVectorizer for text features: ['Tweet']
# 			CountVectorizer fit with vocabulary size = 8618
# 		Warning: Due to memory constraints, ngram feature count is being reduced. Allocate more memory to maximize model quality.
# 		Reducing Vectorizer vocab size from 8618 to 2428 to avoid OOM error
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('object', ['text']) : 1 | ['Tweet']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', ['text_as_category'])  :    1 | ['Tweet']
# 		('int', ['binned', 'text_special']) :   25 | ['Tweet.char_count', 'Tweet.word_count', 'Tweet.capital_ratio', 'Tweet.lower_ratio', 'Tweet.digit_ratio', ...]
# 		('int', ['text_ngram'])             : 2371 | ['__nlp__.00', '__nlp__.000', '__nlp__.10', '__nlp__.100', '__nlp__.10am', ...]
# 	15.6s = Fit runtime
# 	1 features in original data used to generate 2397 features in processed data.
# 	Train Data (Processed) Memory Usage: 314.58 MB (2.4% of available memory)
# Data preprocessing and feature engineering runtime = 16.48s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.03614388156372889, Train Rows: 66668, Val Rows: 2500
# User-specified model hyperparameters to be fit:
# {
# 	'LR': [{}],
# 	'RF': [{}],
# 	'XGB': [{}],
# }
# Fitting 3 L1 models, fit_strategy="sequential" ...
# Fitting model: RandomForest ... Training model for up to 583.52s of the 583.52s of remaining time.
# 	Fitting with cpus=32, gpus=0, mem=0.0/12.0 GB
# 	0.6956	 = Validation score   (accuracy)
# 	53.65s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 528.98s of the 528.98s of remaining time.
# 	Fitting with cpus=24, gpus=0, mem=3.1/11.8 GB
# 	0.7092	 = Validation score   (accuracy)
# 	26.03s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LinearModel ... Training model for up to 502.75s of the 502.75s of remaining time.
# 	Fitting with cpus=32, gpus=0, mem=1.2/11.8 GB
# 	0.6928	 = Validation score   (accuracy)
# 	262.28s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 239.84s of remaining time.
# 	Ensemble Weights: {'XGBoost': 0.875, 'LinearModel': 0.125}
# 	0.7104	 = Validation score   (accuracy)
# 	0.02s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 361.86s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 4207.4 rows/s (2500 batch size)
# Disabling decision threshold calibration for metric `accuracy` due to having fewer than 10000 rows of validation data for calibration, to avoid overfitting (2500 rows).
# 	`accuracy` is generally not improved through threshold calibration. Force calibration via specifying `calibrate_decision_threshold=True`.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("c:\Users\kevin\Documents\GitHub\open-vRAG\political_affiliation\AutogluonModels\politicalAffiliation_tabular")

# %%
# Out:
# --- Model Leaderboard (All Trained Models) ---
#                  model  score_test  score_val eval_metric  pred_time_test  \
# 0         RandomForest    0.928927     0.6956    accuracy        1.003100
# 1              XGBoost    0.840793     0.7092    accuracy        0.685651
# 2  WeightedEnsemble_L2    0.828649     0.7104    accuracy        2.700826
# 3          LinearModel    0.710849     0.6928    accuracy        1.993018
#
#    pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0       0.097378   53.654550                 1.003100                0.097378
# 1       0.084582   26.034742                 0.685651                0.084582
# 2       0.594190  288.330255                 0.022157                0.001021
# 3       0.508588  262.275979                 1.993018                0.508588
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0          53.654550            1       True          1
# 1          26.034742            1       True          2
# 2           0.019534            2       True          4
# 3         262.275979            1       True          3

# %%
save_path2 = 'AutogluonModels/politicalAffiliation_multimodal'
predictor2 = MultiModalPredictor(
    label="label",
    eval_metric="accuracy",
    problem_type="binary",
    output_directory= save_path2
)

predictor2.fit(train_data,
 time_limit=1200,
 presets='good_quality')

# %%
df.iloc[1]['Tweet']
# Out:
# 'rt USER : winter haven resident / alta vista teacher is one of several recognized by USER for national teacher apprecia…'
